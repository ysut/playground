# %%
# Standard modules
from dataclasses import dataclass
from logging import getLogger, StreamHandler, DEBUG, Formatter

# Third party modules
import gffutils
import pybedtools
import pandas as pd
import numpy as np
from pathlib2 import Path
from tqdm import tqdm

# Local modules
from libs.args import parser_setting
from libs.utils import load_config, OutputSettings
# from libs.preprocess import PreProcessExomeSummary
# from libs.modesamples import ModeSamples
# from libs.annolibs.anno import Anno
# from libs.filter.maffilter import MafFilter
# from libs.filter.typefilter import TypeFilter
# from libs.filter.gtfilter import GtFilter
# from libs.filter.counter import counter

# Settings
tqdm.pandas()
logger = getLogger(__name__)
handler = StreamHandler()
handler.setLevel(DEBUG)
logger.setLevel(DEBUG)
logger.addHandler(handler)

# %%
# args = parser_setting()
# dgvfile = f"/work{args['resources']}/DGV/DGV.GS.March2016.50percent.GainLossSep.Final.hg19.gff3"
# URL = 'http://dgv.tcag.ca/dgv/docs/DGV.GS.March2016.50percent.GainLossSep.Final.hg19.gff3'
import os
import requests

args = {}
args['resources'] = '../resources'
dgvfilename='DGV.GS.March2016.50percent.GainLossSep.Final.hg19.gff3'
dgvfile = f"{args['resources']}/{dgvfilename}"
dgvurl='http://dgv.tcag.ca/dgv/docs/DGV.GS.March2016.50percent.GainLossSep.Final.hg19.gff3'

if os.path.exists(dgvfile):
    pass
else:
    try: 
        res = requests.get(dgvurl)
        print('File downloaded')
    except Exception as e:
        print(e)
        print('Error in downloading file')
    
def download_file(url, filename) -> str:
    try:
        res = requests.get(url)
        with open(filename, 'wb') as f:
            f.write(res.content)
        result = f"File {filename} downloaded"
    except Exception as e:
        print(e)
        print('Error in downloading file')
        result = f"Error in downloading file {filename}"
    
    return result

# with open(dgvfile ,mode='wb') as f:
#     f.write(dgvdata)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 17
#      15 else:
#      16     try:
# ---> 17         dgvdata = requests.get(dgvurl).content
#      18         print('File downloaded')
#      19     except Exception as e:
#
# File ~/miniforge3/envs/wesanno/lib/python3.9/site-packages/requests/api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~/miniforge3/envs/wesanno/lib/python3.9/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/miniforge3/envs/wesanno/lib/python3.9/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/miniforge3/envs/wesanno/lib/python3.9/site-packages/requests/sessions.py:747, in Session.send(self, request, **kwargs)
#     744         pass
#     746 if not stream:
# --> 747     r.content
#     749 return r
#
# File ~/miniforge3/envs/wesanno/lib/python3.9/site-packages/requests/models.py:899, in Response.content(self)
#     897         self._content = None
#     898     else:
# --> 899         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     901 self._content_consumed = True
#     902 # don't need to release the connection; that's been handled by urllib3
#     903 # since we exhausted the data.
#
# File ~/miniforge3/envs/wesanno/lib/python3.9/site-packages/requests/models.py:816, in Response.iter_content.<locals>.generate()
#     814 if hasattr(self.raw, "stream"):
#     815     try:
# --> 816         yield from self.raw.stream(chunk_size, decode_content=True)
#     817     except ProtocolError as e:
#     818         raise ChunkedEncodingError(e)
#
# File ~/miniforge3/envs/wesanno/lib/python3.9/site-packages/urllib3/response.py:934, in HTTPResponse.stream(self, amt, decode_content)
#     932 else:
#     933     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
# --> 934         data = self.read(amt=amt, decode_content=decode_content)
#     936         if data:
#     937             yield data
#
# File ~/miniforge3/envs/wesanno/lib/python3.9/site-packages/urllib3/response.py:877, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     874     if len(self._decoded_buffer) >= amt:
#     875         return self._decoded_buffer.get(amt)
# --> 877 data = self._raw_read(amt)
#     879 flush_decoder = amt is None or (amt != 0 and not data)
#     881 if not data and len(self._decoded_buffer) == 0:
#
# File ~/miniforge3/envs/wesanno/lib/python3.9/site-packages/urllib3/response.py:812, in HTTPResponse._raw_read(self, amt)
#     809 fp_closed = getattr(self._fp, "closed", False)
#     811 with self._error_catcher():
# --> 812     data = self._fp_read(amt) if not fp_closed else b""
#     813     if amt is not None and amt != 0 and not data:
#     814         # Platform-specific: Buggy versions of Python.
#     815         # Close the connection when no data is returned
#    (...)
#     820         # not properly close the connection in all cases. There is
#     821         # no harm in redundantly calling close.
#     822         self._fp.close()
#
# File ~/miniforge3/envs/wesanno/lib/python3.9/site-packages/urllib3/response.py:797, in HTTPResponse._fp_read(self, amt)
#     794     return buffer.getvalue()
#     795 else:
#     796     # StringIO doesn't like amt=None
# --> 797     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File ~/miniforge3/envs/wesanno/lib/python3.9/http/client.py:463, in HTTPResponse.read(self, amt)
#     460 if amt is not None:
#     461     # Amount is given, implement using readinto
#     462     b = bytearray(amt)
# --> 463     n = self.readinto(b)
#     464     return memoryview(b)[:n].tobytes()
#     465 else:
#     466     # Amount is not given (unbounded read) so we must check self.length
#     467     # and self.chunked
#
# File ~/miniforge3/envs/wesanno/lib/python3.9/http/client.py:507, in HTTPResponse.readinto(self, b)
#     502         b = memoryview(b)[0:self.length]
#     504 # we do not use _safe_read() here because this may be a .will_close
#     505 # connection, and the user is reading more bytes than will be provided
#     506 # (for example, reading in 1k chunks)
# --> 507 n = self.fp.readinto(b)
#     508 if not n and b:
#     509     # Ideally, we would raise IncompleteRead if the content-length
#     510     # wasn't satisfied, but it might break compatibility.
#     511     self._close_conn()
#
# File ~/miniforge3/envs/wesanno/lib/python3.9/socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
# xhmm = pd.read_table(args['xhmm'], sep='\t', header=0)
xhmm = pd.read_table('/Volumes/vol/work/Github/TestData/proband/xhmm/data.segdup.strvar.haplo.deciph.omim.xcnv.gene.uniq', sep='\t', header=0)
dgv = pd.read_table(dgvfile, sep='\t', header=None)

# %%
import requests
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 dgv
#
# NameError: name 'dgv' is not defined

# %%
proband_id = 'Sample_33727'
xhmm = xhmm[xhmm['SAMPLE'] == proband_id]

# %%
result = []
gff_file = pybedtools.BedTool(dgvfile)

# %%
for index, row in tqdm(xhmm.iterrows(), total=len(xhmm)):
    print(row['INTERVAL'], type(row['INTERVAL']))
# Out:
# 100%|██████████| 23/23 [00:00<00:00, 11236.92it/s]
# 22:20376922-20484649 <class 'str'>
# 7:5959379-6006847 <class 'str'>
# 7:6797208-6845768 <class 'str'>
# 1:1634814-1671096 <class 'str'>
# 13:114514608-114537745 <class 'str'>
# 1:16350194-16360253 <class 'str'>
# 7:100331691-100336336 <class 'str'>
# 11:89499659-89606558 <class 'str'>
# 19:54735516-54755132 <class 'str'>
# 22:24277563-24331509 <class 'str'>
# 17:39661207-39684599 <class 'str'>
# 5:716822-766150 <class 'str'>
# 19:58131427-58153649 <class 'str'>
# 14:20212798-20404861 <class 'str'>
# 1:16383581-16386199 <class 'str'>
# 7:141782174-141785861 <class 'str'>
# 1:149379059-149400463 <class 'str'>
# 14:106050390-106173999 <class 'str'>
# 1:25598938-25655727 <class 'str'>
# 15:22742295-22743698 <class 'str'>
# 1:47608840-47614569 <class 'str'>
# 16:69988136-70208405 <class 'str'>
# 21:10862521-10944887 <class 'str'>

# %%
re.split('[:-]', '21:10862521-10944887')
# Out:
# ['21', '10862521', '10944887']

# %%
import re

for index, row in tqdm(xhmm.iterrows(), total=len(xhmm)):
    position: list = re.split('[:-]', row['INTERVAL'])
    chrom, start, end = position[0], int(position[1]) - 1, int(position[2])

    interval = pybedtools.Interval(chrom, start, end)
    if gff_file.any_hits(interval):
        result.append(True)
    else:
        result.append(False)
# Out:
# 100%|██████████| 23/23 [01:11<00:00,  3.11s/it]

# %%
xhmm.loc[:,'is_in_DGV'] = result
# Out:
# /var/folders/b_/1qjd6n853xbbctck9_20_nt40000gn/T/ipykernel_9376/418515107.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   xhmm['is_in_DGV'] = result

# %%
xhmm
# Out:
#             SAMPLE  CNV                INTERVAL      KB CHR     MID_BP  \
# 41    Sample_33727  DUP    22:20376922-20484649  107.73  22   20430785
# 122   Sample_33727  DEL       7:5959379-6006847   47.47   7    5983113
# 251   Sample_33727  DUP       7:6797208-6845768   48.56   7    6821488
# 395   Sample_33727  DUP       1:1634814-1671096   36.28   1    1652955
# 492   Sample_33727  DUP  13:114514608-114537745   23.14  13  114526176
# 590   Sample_33727  DUP     1:16350194-16360253   10.06   1   16355223
# 636   Sample_33727  DEL   7:100331691-100336336    4.65   7  100334013
# 1194  Sample_33727  DEL    11:89499659-89606558  106.90  11   89553108
# 1288  Sample_33727  DUP    19:54735516-54755132   19.62  19   54745324
# 1373  Sample_33727  DUP    22:24277563-24331509   53.95  22   24304536
# 1599  Sample_33727  DUP    17:39661207-39684599   23.39  17   39672903
# 1684  Sample_33727  DUP         5:716822-766150   49.33   5     741486
# 1767  Sample_33727  DUP    19:58131427-58153649   22.22  19   58142538
# 1804  Sample_33727  DEL    14:20212798-20404861  192.06  14   20308829
# 1805  Sample_33727  DUP     1:16383581-16386199    2.62   1   16384890
# 2056  Sample_33727  DUP   7:141782174-141785861    3.69   7  141784017
# 2184  Sample_33727  DEL   1:149379059-149400463   21.41   1  149389761
# 2262  Sample_33727  DUP  14:106050390-106173999  123.61  14  106112194
# 2327  Sample_33727  DEL     1:25598938-25655727   56.79   1   25627332
# 2460  Sample_33727  DUP    15:22742295-22743698    1.40  15   22742996
# 2702  Sample_33727  DUP     1:47608840-47614569    5.73   1   47611704
# 2935  Sample_33727  DEL    16:69988136-70208405  220.27  16   70098270
# 2978  Sample_33727  DEL    21:10862521-10944887   82.37  21   10903704
#
#              TARGETS  NUM_TARG  Q_EXACT  Q_SOME  ...  Q_STOP  MEAN_RD  \
# 41    182045..182049         5       45      99  ...      41     8.03
# 122     73740..73748         9        7      78  ...       7    -2.98
# 251     73891..73901        11        4      94  ...       4     2.95
# 395         264..277        14       15      46  ...      16     2.28
# 492   130632..130639         8       58      95  ...      37     6.37
# 590       1922..1935        14        8      99  ...      10     2.94
# 636     78565..78568         4       44      93  ...      17    -5.62
# 1194  112824..112830         7        9      51  ...      14    -3.06
# 1288  173945..173949         5        5      96  ...       6     4.39
# 1373  182472..182481        10        4      99  ...       4     3.81
# 1599  156196..156205        10       38      98  ...      34     3.76
# 1684    54397..54403         7        8      96  ...       8     4.56
# 1767  174591..174597         7       12      53  ...      34     3.05
# 1804  130711..130721        11       16      95  ...      26    -3.59
# 1805      1951..1953         3        6      33  ...       4     4.57
# 2056    81264..81267         4       21      30  ...       6     3.76
# 2184    10754..10757         4       23      99  ...      59    -6.06
# 2262  136822..136834        13       10      96  ...      37     4.60
# 2327      3137..3145         9        4      50  ...      12    -2.71
# 2460  136918..136918         1       30      30  ...      20    10.00
# 2702      5939..5943         5       17      87  ...      29     4.17
# 2935  149407..149424        18       10      82  ...       9    -2.67
# 2978  179526..179533         8       10      32  ...      24    -2.72
#
#       MEAN_ORIG_RD      SegDup  StrVar  Haplo_Insuff_Trip  Decipher  \
# 41           75.86  100.000000   100.0                0.0     100.0
# 122          23.45  100.000000   100.0                0.0       0.0
# 251          33.11  100.000000   100.0                0.0       0.0
# 395          54.51   78.309401   100.0                0.0     100.0
# 492          76.78    0.000000   100.0                0.0       0.0
# 590          55.45  100.000000   100.0                0.0       0.0
# 636           0.00    0.000000   100.0                0.0       0.0
# 1194         18.59  100.000000   100.0                0.0       0.0
# 1288         80.25   26.874650   100.0                0.0       0.0
# 1373         49.68   95.877435   100.0                0.0       0.0
# 1599         66.86    0.000000   100.0                0.0       0.0
# 1684         67.94  100.000000   100.0                0.0     100.0
# 1767         64.06    0.000000   100.0                0.0       0.0
# 1804         40.92   59.882643   100.0                0.0       0.0
# 1805         67.06  100.000000   100.0                0.0       0.0
# 2056         73.19  100.000000   100.0                0.0       0.0
# 2184          0.27  100.000000   100.0                0.0       0.0
# 2262         78.76   94.790066   100.0                0.0       0.0
# 2327         25.49  100.000000   100.0                0.0       0.0
# 2460        144.24  100.000000   100.0                0.0       0.0
# 2702         72.82  100.000000   100.0                0.0       0.0
# 2935         31.82   93.866164   100.0                0.0       0.0
# 2978         70.49   99.721976   100.0                0.0       0.0
#
#         Omimgene                                               gene  is_in_DGV
# 41    100.000000                            TMEM191B,PI4KAP1,RIMBP3      False
# 122     0.000000                              RSPH10B2,RSPH10B,CCZ1      False
# 251     0.000000                             RSPH10B2,RSPH10B,CCZ1B      False
# 395     0.000000                             SLC35E2A,CDK11A,CDK11B      False
# 492     0.000000                                      TMEM255B,GAS6      False
# 590   100.000000                                             CLCNKA      False
# 636     0.000000                                                ZAN      False
# 1194    0.000000                   TRIM49,TRIM64B,TRIM53AP,TRIM51EP      False
# 1288    0.000000                               LILRA6,LILRB5,LILRB3      False
# 1373  100.000000                              GSTT2B,DDT,GSTT2,DDTL      False
# 1599    5.168213                          MIR6510,KRT15,KRT13,KRT19      False
# 1684    0.000000                                           ZDHHC11B      False
# 1767    0.000000                                      ZNF211,ZNF134      False
# 1804  100.000000          OR4K1,OR4K2,OR4M1,OR4K5,OR4K3,OR4N2,OR4Q3      False
# 1805  100.000000                                            FAM131C      False
# 2056  100.000000                                               MGAM      False
# 2184  100.000000                               HIST2H2BB,HIST2H3PS2      False
# 2262    0.000000                         MIR8071-2,ELK2AP,MIR8071-1      False
# 2327    0.000000                                                RHD      False
# 2460    0.000000                                 GOLGA6L22,GOLGA6L1      False
# 2702  100.000000                                            CYP4A22      False
# 2935    0.000000  PDXDC2P-NPIPB14P,CLEC18C,LOC400541,PDPR,MIR197...      False
# 2978    0.000000                                               TPTE      False
#
# [23 rows x 22 columns]

# %%
xhmm
# Out:
#             SAMPLE  CNV                INTERVAL      KB CHR     MID_BP  \
# 41    Sample_33727  DUP    22:20376922-20484649  107.73  22   20430785
# 122   Sample_33727  DEL       7:5959379-6006847   47.47   7    5983113
# 251   Sample_33727  DUP       7:6797208-6845768   48.56   7    6821488
# 395   Sample_33727  DUP       1:1634814-1671096   36.28   1    1652955
# 492   Sample_33727  DUP  13:114514608-114537745   23.14  13  114526176
# 590   Sample_33727  DUP     1:16350194-16360253   10.06   1   16355223
# 636   Sample_33727  DEL   7:100331691-100336336    4.65   7  100334013
# 1194  Sample_33727  DEL    11:89499659-89606558  106.90  11   89553108
# 1288  Sample_33727  DUP    19:54735516-54755132   19.62  19   54745324
# 1373  Sample_33727  DUP    22:24277563-24331509   53.95  22   24304536
# 1599  Sample_33727  DUP    17:39661207-39684599   23.39  17   39672903
# 1684  Sample_33727  DUP         5:716822-766150   49.33   5     741486
# 1767  Sample_33727  DUP    19:58131427-58153649   22.22  19   58142538
# 1804  Sample_33727  DEL    14:20212798-20404861  192.06  14   20308829
# 1805  Sample_33727  DUP     1:16383581-16386199    2.62   1   16384890
# 2056  Sample_33727  DUP   7:141782174-141785861    3.69   7  141784017
# 2184  Sample_33727  DEL   1:149379059-149400463   21.41   1  149389761
# 2262  Sample_33727  DUP  14:106050390-106173999  123.61  14  106112194
# 2327  Sample_33727  DEL     1:25598938-25655727   56.79   1   25627332
# 2460  Sample_33727  DUP    15:22742295-22743698    1.40  15   22742996
# 2702  Sample_33727  DUP     1:47608840-47614569    5.73   1   47611704
# 2935  Sample_33727  DEL    16:69988136-70208405  220.27  16   70098270
# 2978  Sample_33727  DEL    21:10862521-10944887   82.37  21   10903704
#
#              TARGETS  NUM_TARG  Q_EXACT  Q_SOME  ...  Q_START  Q_STOP  \
# 41    182045..182049         5       45      99  ...        4      41
# 122     73740..73748         9        7      78  ...       19       7
# 251     73891..73901        11        4      94  ...       14       4
# 395         264..277        14       15      46  ...       15      16
# 492   130632..130639         8       58      95  ...       14      37
# 590       1922..1935        14        8      99  ...        4      10
# 636     78565..78568         4       44      93  ...       12      17
# 1194  112824..112830         7        9      51  ...       10      14
# 1288  173945..173949         5        5      96  ...       10       6
# 1373  182472..182481        10        4      99  ...       39       4
# 1599  156196..156205        10       38      98  ...       12      34
# 1684    54397..54403         7        8      96  ...       11       8
# 1767  174591..174597         7       12      53  ...       12      34
# 1804  130711..130721        11       16      95  ...       14      26
# 1805      1951..1953         3        6      33  ...       17       4
# 2056    81264..81267         4       21      30  ...        5       6
# 2184    10754..10757         4       23      99  ...       23      59
# 2262  136822..136834        13       10      96  ...       10      37
# 2327      3137..3145         9        4      50  ...        4      12
# 2460  136918..136918         1       30      30  ...       29      20
# 2702      5939..5943         5       17      87  ...       16      29
# 2935  149407..149424        18       10      82  ...       13       9
# 2978  179526..179533         8       10      32  ...       10      24
#
#       MEAN_RD  MEAN_ORIG_RD      SegDup  StrVar  Haplo_Insuff_Trip  Decipher  \
# 41       8.03         75.86  100.000000   100.0                0.0     100.0
# 122     -2.98         23.45  100.000000   100.0                0.0       0.0
# 251      2.95         33.11  100.000000   100.0                0.0       0.0
# 395      2.28         54.51   78.309401   100.0                0.0     100.0
# 492      6.37         76.78    0.000000   100.0                0.0       0.0
# 590      2.94         55.45  100.000000   100.0                0.0       0.0
# 636     -5.62          0.00    0.000000   100.0                0.0       0.0
# 1194    -3.06         18.59  100.000000   100.0                0.0       0.0
# 1288     4.39         80.25   26.874650   100.0                0.0       0.0
# 1373     3.81         49.68   95.877435   100.0                0.0       0.0
# 1599     3.76         66.86    0.000000   100.0                0.0       0.0
# 1684     4.56         67.94  100.000000   100.0                0.0     100.0
# 1767     3.05         64.06    0.000000   100.0                0.0       0.0
# 1804    -3.59         40.92   59.882643   100.0                0.0       0.0
# 1805     4.57         67.06  100.000000   100.0                0.0       0.0
# 2056     3.76         73.19  100.000000   100.0                0.0       0.0
# 2184    -6.06          0.27  100.000000   100.0                0.0       0.0
# 2262     4.60         78.76   94.790066   100.0                0.0       0.0
# 2327    -2.71         25.49  100.000000   100.0                0.0       0.0
# 2460    10.00        144.24  100.000000   100.0                0.0       0.0
# 2702     4.17         72.82  100.000000   100.0                0.0       0.0
# 2935    -2.67         31.82   93.866164   100.0                0.0       0.0
# 2978    -2.72         70.49   99.721976   100.0                0.0       0.0
#
#         Omimgene                                               gene
# 41    100.000000                            TMEM191B,PI4KAP1,RIMBP3
# 122     0.000000                              RSPH10B2,RSPH10B,CCZ1
# 251     0.000000                             RSPH10B2,RSPH10B,CCZ1B
# 395     0.000000                             SLC35E2A,CDK11A,CDK11B
# 492     0.000000                                      TMEM255B,GAS6
# 590   100.000000                                             CLCNKA
# 636     0.000000                                                ZAN
# 1194    0.000000                   TRIM49,TRIM64B,TRIM53AP,TRIM51EP
# 1288    0.000000                               LILRA6,LILRB5,LILRB3
# 1373  100.000000                              GSTT2B,DDT,GSTT2,DDTL
# 1599    5.168213                          MIR6510,KRT15,KRT13,KRT19
# 1684    0.000000                                           ZDHHC11B
# 1767    0.000000                                      ZNF211,ZNF134
# 1804  100.000000          OR4K1,OR4K2,OR4M1,OR4K5,OR4K3,OR4N2,OR4Q3
# 1805  100.000000                                            FAM131C
# 2056  100.000000                                               MGAM
# 2184  100.000000                               HIST2H2BB,HIST2H3PS2
# 2262    0.000000                         MIR8071-2,ELK2AP,MIR8071-1
# 2327    0.000000                                                RHD
# 2460    0.000000                                 GOLGA6L22,GOLGA6L1
# 2702  100.000000                                            CYP4A22
# 2935    0.000000  PDXDC2P-NPIPB14P,CLEC18C,LOC400541,PDPR,MIR197...
# 2978    0.000000                                               TPTE
#
# [23 rows x 21 columns]
